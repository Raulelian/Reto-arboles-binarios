# %% [markdown]
# # Ejercicio 8. Árboles binarios
#
# ## Enunciado
#
# Un árbol binario es una estructura de datos en la cual cada nodo tiene un valor y puede como máximo dos hijos que se denominan hijo izquierdo e hijo derecho. Un nodo no puede tener más de dos hijos (por eso el nombre de _binario_) pero puede tener menos, es decir, solamente puede tener cero, uno o dos hijos.
#
# Si un nodo no tiene hijos, se denomina _nodo externo_, en otro caso se denomina _nodo interno_.
#
# En Python, podemos representar estos árboles usando listas de forma que cada nodo será una lista con tres elementos donde:
#
# - El primer elemento será el valor del nodo
# - El segundo elemento será el hijo izquierdo
# - El tercer elemento será el hijo derecho
#
# Según esto, el siguiente árbol
#
# ![Ejemplo de árbol binario](data:image/png;base64,...)
#
#
# quedaría representado de la siguiente manera:

# %%
arbol_binario = [
  1,
  [7,
    [2,
      [],
      []],
    [6, 
      [5,
        [],
        []],
      [11,
        [],
        []]]],
    [9,
      [],
      [9, 
        [5,
          [],
          []],
        []]]]

# %% [markdown]
# Escribe un fragmento de código que obtenda el mayor valor almacenado en este árbol binario.

# %% [markdown]
# ## Ayuda a la implementación
#
# En tu implementación necesitarás realizar un bucle que recorra todos los nodos del árbol. Puedes ir recorriendo los hijos a la izquierda y guardando los hijos a la derecha en una lista temporal. Así puedes ir guardadndo nodos en la pila para produndizar en el árbol y "sacarlo" de la lista (que actúa como pila) para volver a subir al nivel anterior.
